# %%
s = "Programming"
print(s[:3])
print(s[3:7])
# Out:
# Pro
# gram

# %%
#Print the last 3 characters of the string using slicing
print(s[-3:])
# Out:
# ing

# %%
#Print all characters except the first and last character.
print(s[1:10])
# Out:
# rogrammin

# %%
#Reverse the string using slicing only.
print(s[::-1])
# Out:
# gnimmargorP

# %%
#extract the username only.
email = "vinayak123@gmail.com"
print(email[:7])
#extract gmail
print(email[12:16])
# Out:
# vinayak
# mail

# %%
#extarct python using slicing
url = "https://www.python.org"
print(url[12:18])
# Out:
# python

# %%
#extact day month year
date = "04-03-2026"
print(date[:2]) #day
print(date[3:5])#month
print(date[-4:])#year
# Out:
# 04
# 03
# 2026

# %%
#extract 'very' slicing
sentence = "Python_is_very_powerful"
print(sentence[10:14])
# Out:
# very

# %%
s = "DataScience"
#Print every second character from the string in reverse order.
print(s[::-2])
# Out:
# eniStD

# %%
#Print every second character from the string in reverse order.
print(s[-5::])
# Out:
# ience

# %%
#Reverse only the first 4 characters of the string
print(s[:4][::-1])
# Out:
# ataD

# %%
#Print characters from index 8 to index 3 in reverse order.
print(s[3:9][::-1])
# Out:
# neicSa

# %%
#print acegi
s = "abcdefghij"
print(s[::2])
# Out:
# acegi

# %%
# Write a program that checks whether a string is a 
# palindrome using slicing.
s = "Naman"
rev = s[::-1]
print(rev)
if rev.casefold() == s.casefold():
    print("palindrome")
else:
    print("Not palindrome")
# Out:
# namaN
# palindrome

# %%
#Negative slicing
s = "ArtificialIntelligence"
print(s[-12::])
# Out:
# Intelligence

# %%
#convert it into reverse and lower
s = "PYTHON"
print(s[::-1].lower())
# Out:
# nohtyp

# %%
s = "0123456789"
print(s[1::2][::-1])
# Out:
# 97531

# %%
s = "abcdefghijklmnopqrstuvwxyz"
print(s[::-1][::2])
# Out:
# zxvtrpnljhfdb

# %%
s = "0123456789"
print(s[::2][::-1])
# Out:
# 86420

# %%
s = "ComputerScience"
print(s[7:10])
# Out:
# rSc

# %%
#Print the string starting from index 10 to the beginning 
# in reverse.
s = "ArtificialIntelligence"
print(s[:11][::-1])
# Out:
# IlaicifitrA

# %%
#extract only numbers
s = "AA11BB22CC33"
print(s[2::4])
# Out:
# 123

# %%
s = "1234abcd5678"
print(s[4:8])
# Out:
# abcd

# %%
#Extract "three" using slicing only
s = "one_two_three_four"
print(s[8:13])
# Out:
# three

# %%
#Rearrange using slicing to 04-03-2026
s = "2026/03/04"
print(s[8:10] + "-" + s[5:7] + "-" + s[0:4])
# Out:
# 04-03-2026

# %%
#print HELLOdlrow
s = "HELLOworld"
print(s[:5]+s[-5:][::-1])
# Out:
# HELLOdlrow

# %%
#print every 3rd character
s = "abcdefghijklmnop"
print(s[::3])
# Out:
# adgjmp

# %%
s = "PYTHONPROGRAMMING"
print(s[::2])
#Print characters at odd indexes in reverse.
print(s[1::2][::-1])
# Out:
# PTOPORMIG
# NMAGRNHY

# %%
s = "ABCDEFGHIJK"
print(s[::2])
# Out:
# ACEGIK
