# %%
books = [
    ("Atomic Habits", "James Clear", 2018),
    ("Deep Work", "Cal Newport", 2016),
    ("Clean Code", "Robert Martin", 2008)
]

# %%
for book,author,year in books:
    print(f"Book: {book}, Author: {author}, Year: {year}")
# Out:
# Book: Atomic Habits, Author: James Clear, Year: 2018
# Book: Deep Work, Author: Cal Newport, Year: 2016
# Book: Clean Code, Author: Robert Martin, Year: 2008

# %%
for book,author,year in books:
    if year > 2010:
       print(f"Book: {book}, Author: {author}, Year: {year}")
# Out:
# Book: Atomic Habits, Author: James Clear, Year: 2018
# Book: Deep Work, Author: Cal Newport, Year: 2016

# %%
books = [
    ("Atomic Habits", "James Clear", 2018, [
        (1, "The Surprising Power of Atomic Habits"),
        (2, "How Your Habits Shape Your Identity"),
        (3, "How to Build Better Habits")
    ]),
    
    ("Deep Work", "Cal Newport", 2016, [
        (1, "Deep Work is Valuable"),
        (2, "Deep Work is Rare"),
        (3, "Deep Work is Meaningful")
    ]),
    
    ("Clean Code", "Robert Martin", 2008, [
        (1, "Clean Code"),
        (2, "Meaningful Names"),
        (3, "Functions")
    ]),
    
    ("The Pragmatic Programmer", "Andrew Hunt", 1999, [
        (1, "A Pragmatic Philosophy"),
        (2, "A Pragmatic Approach"),
        (3, "The Basic Tools")
    ]),
    
    ("Python Crash Course", "Eric Matthes", 2019, [
        (1, "Getting Started"),
        (2, "Variables and Data Types"),
        (3, "Introducing Lists")
    ])
]

# %%
for index,(title,author,year,chapters) in enumerate(books):
    print(f"{index+1} : {title}")
# Out:
# 1 : Atomic Habits
# 2 : Deep Work
# 3 : Clean Code
# 4 : The Pragmatic Programmer
# 5 : Python Crash Course

# %%
CHAPTER_INDEX_LIST = 3
for index,(title,author,year,chapters) in enumerate(books):
    print(f"{index+1} : {title}")

while True:
    choice = int(input("Choose a book"))
    chapters = books[choice-1][CHAPTER_INDEX_LIST ]
    if chapters != None :
       for index,(chapter_no,chapter) in enumerate(chapters):
           print(f"{chapter_no} : {chapter}")
        choice_chapter = int(input("Choose a chapter"))
        print("Reading")
# Out:
# 1 : Atomic Habits
# 2 : Deep Work
# 3 : Clean Code
# 4 : The Pragmatic Programmer
# 5 : Python Crash Course
# [(1, 'Clean Code'), (2, 'Meaningful Names'), (3, 'Functions')]
# 1 : Clean Code
# 2 : Meaningful Names
# 3 : Functions
# [(1, 'Getting Started'), (2, 'Variables and Data Types'), (3, 'Introducing Lists')]
# 1 : Getting Started
# 2 : Variables and Data Types
# 3 : Introducing Lists
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       2     print(f"{index+1} : {title}")
#       4 while True:
# ----> 5     choice = int(input("Choose a book"))
#       6     chapters = books[choice-1][3]
#       7     print(chapters)
#
# ValueError: invalid literal for int() with base 10: ''
