# %%
from data import plants_list

for plant in plants_list:
    if plant.lifecycle.casefold() == 'perennial':
        print(plant.name)
# Out:
# Bellflower
# China Pink
# Daffodil
# Golden Hakone Grass
# Iris
# Lavender
# Peony
# Red Hot Poker
# Tiger Lily

# %%
print(list(filter(lambda plant:plant.plant_type == 'Flower',plants_list)))
# Out:
# [Plant(name='Bellflower', scientific_name='Campanula', lifecycle='perennial', plant_type='Flower'), Plant(name='China Pink', scientific_name='Dianthus', lifecycle='Perennial', plant_type='Flower'), Plant(name='Daffodil', scientific_name='Narcissus', lifecycle='Perennial', plant_type='Flower'), Plant(name='Evening Primrose', scientific_name='Oenothera', lifecycle='Biennial', plant_type='Flower'), Plant(name='French Marigold', scientific_name='Tagetes patula', lifecycle='Annual', plant_type='Flower'), Plant(name='Iris', scientific_name='Iris', lifecycle='Perennial', plant_type='Flower'), Plant(name="Queen Anne's Lace", scientific_name='Daucus carota', lifecycle='Biennial', plant_type='Flower'), Plant(name='Red Hot Poker', scientific_name='Kniphofia', lifecycle='Perennial', plant_type='Flower'), Plant(name='Snapdragon', scientific_name='Antirrhinum majus', lifecycle='Annual', plant_type='Flower'), Plant(name='Sunflower', scientific_name='Helianthus', lifecycle='Annual', plant_type='Flow
# ...

# %%
print(list(map(lambda x : f"{x.name} - {x.plant_type}",plants_list)))
# Out:
# ['Andromeda - Shrub', 'Bellflower - Flower', 'China Pink - Flower', 'Daffodil - Flower', 'Evening Primrose - Flower', 'French Marigold - Flower', 'Golden Hakone Grass - Grass', 'Hydrangea - Shrub', 'Iris - Flower', 'Japanese Camellia - Shrub', 'Lavender - Shrub', 'Lilac - Shrub', 'Magnolia - Shrub', 'Peony - Shrub', "Queen Anne's Lace - Flower", 'Red Hot Poker - Flower', 'Snapdragon - Flower', 'Sunflower - Flower', 'Tiger Lily - Flower', 'Witch Hazel - Shrub']

# %%
print([plant.name for plant in plants_list if plant.lifecycle.casefold() == "perennial" and plant.plant_type == "Flower"])
# Out:
# ['Bellflower', 'China Pink', 'Daffodil', 'Iris', 'Red Hot Poker', 'Tiger Lily']

# %%
from data import plants_dict
for plant,details in plants_dict.items():
    if details.lifecycle == 'Annual':
       print(plant)
# Out:
# French Marigold
# Snapdragon
# Sunflower

# %%
annual_plants = [plant for plant,details in plants_dict.items() if details.lifecycle.casefold() == 'annual']
print(annual_plants)
# Out:
# ['French Marigold', 'Snapdragon', 'Sunflower']

# %%
#count total number of flower plants
import functools
count_flow = functools.reduce(
    lambda acc,plant:acc + (1 if plant.plant_type == 'FLower' else 0),
    plants_list,0
)

# %%
count_flow = sum(1 for plant in plants_list if plant.plant_type == "Flower")
print(count_flow)
# Out:
# 11

# %%
print(sorted(plants_list,key=lambda x:x.scientific_name))
# Out:
# [Plant(name='Snapdragon', scientific_name='Antirrhinum majus', lifecycle='Annual', plant_type='Flower'), Plant(name='Japanese Camellia', scientific_name='Camellia japonica', lifecycle='Evergreen', plant_type='Shrub'), Plant(name='Bellflower', scientific_name='Campanula', lifecycle='perennial', plant_type='Flower'), Plant(name="Queen Anne's Lace", scientific_name='Daucus carota', lifecycle='Biennial', plant_type='Flower'), Plant(name='China Pink', scientific_name='Dianthus', lifecycle='Perennial', plant_type='Flower'), Plant(name='Golden Hakone Grass', scientific_name='Hakonechloa macra', lifecycle='Perennial', plant_type='Grass'), Plant(name='Witch Hazel', scientific_name='Hamamelis', lifecycle='Deciduous', plant_type='Shrub'), Plant(name='Sunflower', scientific_name='Helianthus', lifecycle='Annual', plant_type='Flower'), Plant(name='Hydrangea', scientific_name='Hydrangea', lifecycle='evergreen', plant_type='Shrub'), Plant(name='Iris', scientific_name='Iris', lifecycle='Perennial', p
# ...

# %%
from data import plants_list

# %%
print(any(plant.name for plant in plants_list if "Grass" in plant.name))
# Out:
# True

# %%
print(any(plant.plant_type == 'Shrub' for plant in plants_list))
# Out:
# True
