# %%
import os
print(os.listdir())
# Out:
# ['practice1.ipynb', 'practice2.ipynb']

# %%
print(os.getcwd())
# Out:
# d:\denama\python\27_3\29_3

# %%
os.mkdir("demo")

# %%
os.chdir('../')
print(os.getcwd())
# Out:
# d:\denama\python\27_3

# %%
os.chdir('./demo')

# %%
print(os.getcwd())
# Out:
# d:\denama\python\27_3\29_3\demo

# %%
file_path = "data.txt"

if os.path.exists(file_path):
    print(f"The file '{file_path}' exists.")
else:
    print(f"The file '{file_path}' does not exist.")
# Out:
# The file 'data.txt' does not exist.

# %%
path = 'demo'
for i in range(5):
    file = f"file{i}.txt"
    os.path.join(file,path)
